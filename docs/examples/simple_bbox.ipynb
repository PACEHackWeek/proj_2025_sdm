# %% [markdown]
# # simple_bbox
#
# Make a map of world with your study area in red.

# %%
import sdm

bbox = [-25, 10, -10, 30]
sdm.simple_bbox(bbox, projection='Robinson')

# %%
sdm.simple_bbox(bbox, projection='globe')

# %%
sdm.simple_bbox(bbox)
